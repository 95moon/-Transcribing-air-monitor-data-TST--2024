# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
import os

# %%
##################### 获取路径下的不用年份_文件夹名称 ####################
name_list = os.listdir('/mnt/e/_03_data_air/sties')
name_list
# Out:
# ['站点_20140513-20141231',
#  '站点_20150101-20151231',
#  '站点_20160101-20161231',
#  '站点_20170101-20171231',
#  '站点_20180101-20181231',
#  '站点_20190101-20191231',
#  '站点_20200101-20201231',
#  '站点_20210101-20211231',
#  '站点_20220101-20221231',
#  '站点_20230101-20231216']

# %%
######################## path1（自定义），某年路径 #####################
path1 = os.path.join('/mnt/e/_03_data_air/sties','站点_20190101-20191231')
path1
# Out:
# '/mnt/e/_03_data_air/sties/站点_20190101-20191231'

# %%
hour_list = np.arange(0, 24)  # 用于后续小时判断
for name in os.listdir(path1): # <<<<<<<<<<<<<<<<<<<（导入路径）可以用上面的name_list替换
    # 从os.listdir是文件名称列表，通过名称变换实现日期变换
    print(name)
    path = os.path.join(path1, name)  # <<<<<<<<<<<<<<<<（导入路径）拼接文档路径和文件名称形成文件路径
    
    df = pd.read_csv(path, encoding='UTF-8')  # 打开当天文件，且命名为df
    
    need_processing = False  # 是否需要处理的标志，设置为否！！！！！！！！！！！！！！！

    for i in hour_list:
        try: # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<这里可能存在打开一个空文件
            count_num = df[df['hour'] == i]['date'].count()
            # “df[df['hour'] == i]”中间的 == 会产生一个bool索引。导入bool索引之后对其date列有多少数据进行统计。
            # date也可以换成别的，但是date一定有数据（因为只有当date一列其他所有监测值为空date则跳过）

            if count_num < 15:
                need_processing = True  # 设置标志为 True，表示需要处理！！！！！！！！！！
                insert_index = i * 15  # 插入的索引位置
            
                empty_row = pd.Series(index=df.columns)
                # 空白行模版构建，series和df拼接是需要转换，见后面。
                # 此外df.columns获取列名称，df在前面就已经打开了，所以可以获取，列名称实际上是一些站点的代号，这些操作用于df转换。

                date_value = df['date'].iloc[0]  # 这 是在for循环中某个i小时的操作，因此，该段代码为获取当前小时日期数据。
                empty_row['date'] = date_value  # 赋值给空series，中日期数据。
                empty_row['hour'] = i  # 赋值小时数据

                df = pd.concat([df.iloc[:insert_index], pd.DataFrame([empty_row] * (15 - count_num), columns=df.columns),df.iloc[insert_index:]]).reset_index(drop=True)
                # pd.DataFrame——将series转化为df才能拼接
                # 拼接三个部分insert_index之前（不包括该行），新增行和insert_index之后行
                # reset_index(drop=True) 是用于重置DataFrame的索引，并丢弃原来的索引，如果不丢弃，原来索引会变成一列新数据。
                # 插入的行数为空白行×倍数“15-count_num”
        except Exception as e:
            print(f'{e}')
            break # 跳过这些空白文件

    # 如果需要处理，则将修改后的 DataFrame 写入新文件
    if need_processing:
        ################## （自定义）每次运行确保这里没有文件 ####################
        df.to_csv(f'/mnt/e/_03_data_air/修改/{name}', index=False)
# Out:
# china_sites_20190101.csv
# china_sites_20190102.csv
# china_sites_20190103.csv
# china_sites_20190104.csv
# china_sites_20190105.csv
# china_sites_20190106.csv
# china_sites_20190107.csv
# china_sites_20190108.csv
# china_sites_20190109.csv
# china_sites_20190110.csv
# china_sites_20190111.csv
# china_sites_20190112.csv
# china_sites_20190113.csv
# china_sites_20190114.csv
# china_sites_20190115.csv
# china_sites_20190116.csv
# china_sites_20190117.csv
# china_sites_20190118.csv
# china_sites_20190119.csv
# china_sites_20190120.csv
# china_sites_20190121.csv
# china_sites_20190122.csv
# china_sites_20190123.csv
# china_sites_20190124.csv
# china_sites_20190125.csv
# china_sites_20190126.csv
# china_sites_20190127.csv
# china_sites_20190128.csv
# china_sites_20190129.csv
# china_sites_20190130.csv
# china_sites_20190131.csv
# china_sites_20190201.csv
# china_sites_20190202.csv
# china_sites_20190203.csv
# china_sites_20190204.csv
# china_sites_20190205.csv
# china_sites_20190206.csv
# china_sites_20190207.csv
# china_sites_20190208.csv
# china_sites_20190209.csv
# china_sites_20190210.csv
# china_sites_20190211.csv
# china_sites_20190212.csv
# china_sites_20190213.csv
# china_sites_20190214.csv
# china_sites_20190215.csv
# china_sites_20190216.csv
# china_sites_20190217.csv
# china_sites_20190218.csv
# china_sites_20190219.csv
# china_sites_20190220.csv
# china_sites_20190221.csv
# china_sites_20190222.csv
# china_sites_20190223.csv
# china_sites_20190224.csv
# china_sites_20190225.csv
# china_sites_20190226.csv
# china_sites_20190227.csv
# china_sites_20190228.csv
# china_sites_20190301.csv
# china_sites_20190302.csv
# china_sites_20190303.csv
# china_sites_20190304.csv
# china_sites_20190305.csv
# china_sites_20190306.csv
# china_sites_20190307.csv
# china_sites_20190308.csv
# china_sites_20190309.csv
# china_sites_20190310.csv
# china_sites_20190311.csv
# china_sites_20190312.csv
# china_sites_20190313.csv
# china_sites_20190314.csv
# china_sites_20190315.csv
# china_sites_20190316.csv
# china_sites_20190317.csv
# china_sites_20190318.csv
# china_sites_20190319.csv
# china_sites_20190320.csv
# china_sites_20190321.csv
# china_sites_20190322.csv
# china_sites_20190323.csv
# china_sites_20190324.csv
# china_sites_20190325.csv
# china_sites_20190326.csv
# china_sites_20190327.csv
# china_sites_20190328.csv
# china_sites_20190329.csv
# china_sites_20190330.csv
# china_sites_20190331.csv
# china_sites_20190401.csv
# china_sites_20190402.csv
# china_sites_20190403.csv
# china_sites_20190404.csv
# china_sites_20190405.csv
# china_sites_20190406.csv
# china_sites_20190407.csv
# china_sites_20190408.csv
# china_sites_20190409.csv
# china_sites_20190410.csv
# china_sites_20190411.csv
# china_sites_20190412.csv
# china_sites_20190413.csv
# china_sites_20190414.csv
# china_sites_20190415.csv
# china_sites_20190416.csv
# china_sites_20190417.csv
# china_sites_20190418.csv
# china_sites_20190419.csv
# china_sites_20190420.csv
# china_sites_20190421.csv
# china_sites_20190422.csv
# china_sites_20190423.csv
# china_sites_20190424.csv
# china_sites_20190425.csv
# china_sites_20190426.csv
# china_sites_20190427.csv
# china_sites_20190428.csv
# china_sites_20190429.csv
# china_sites_20190430.csv
# china_sites_20190501.csv
# china_sites_20190502.csv
# china_sites_20190503.csv
# china_sites_20190504.csv
# china_sites_20190505.csv
# china_sites_20190506.csv
# china_sites_20190507.csv
# china_sites_20190508.csv
# china_sites_20190509.csv
# china_sites_20190510.csv
# china_sites_20190511.csv
# china_sites_20190512.csv
# china_sites_20190513.csv
# china_sites_20190514.csv
# china_sites_20190515.csv
# china_sites_20190516.csv
# china_sites_20190517.csv
# china_sites_20190518.csv
# china_sites_20190519.csv
# china_sites_20190520.csv
# china_sites_20190521.csv
# china_sites_20190522.csv
# china_sites_20190523.csv
# china_sites_20190524.csv
# china_sites_20190525.csv
# china_sites_20190526.csv
# china_sites_20190527.csv
# china_sites_20190528.csv
# china_sites_20190529.csv
# china_sites_20190530.csv
# china_sites_20190531.csv
# china_sites_20190601.csv
# china_sites_20190602.csv
# china_sites_20190603.csv
# china_sites_20190604.csv
# china_sites_20190605.csv
# china_sites_20190606.csv
# china_sites_20190607.csv
# china_sites_20190608.csv
# china_sites_20190609.csv
# china_sites_20190610.csv
# china_sites_20190611.csv
# china_sites_20190612.csv
# china_sites_20190613.csv
# china_sites_20190614.csv
# china_sites_20190615.csv
# china_sites_20190616.csv
# china_sites_20190617.csv
# china_sites_20190618.csv
# china_sites_20190619.csv
# china_sites_20190620.csv
# china_sites_20190621.csv
# china_sites_20190622.csv
# china_sites_20190623.csv
# china_sites_20190624.csv
# china_sites_20190625.csv
# china_sites_20190626.csv
# china_sites_20190627.csv
# china_sites_20190628.csv
# china_sites_20190629.csv
# china_sites_20190630.csv
# china_sites_20190701.csv
# china_sites_20190702.csv
# china_sites_20190703.csv
# china_sites_20190704.csv
# china_sites_20190705.csv
# china_sites_20190706.csv
# china_sites_20190707.csv
# china_sites_20190708.csv
# china_sites_20190709.csv
# china_sites_20190710.csv
# china_sites_20190711.csv
# china_sites_20190712.csv
# china_sites_20190713.csv
# china_sites_20190714.csv
# china_sites_20190715.csv
# china_sites_20190716.csv
# china_sites_20190717.csv
# china_sites_20190718.csv
# china_sites_20190719.csv
# china_sites_20190720.csv
# china_sites_20190721.csv
# china_sites_20190722.csv
# china_sites_20190723.csv
# china_sites_20190724.csv
# china_sites_20190725.csv
# china_sites_20190726.csv
# china_sites_20190727.csv
# china_sites_20190728.csv
# china_sites_20190729.csv
# china_sites_20190730.csv
# china_sites_20190731.csv
# china_sites_20190801.csv
# china_sites_20190802.csv
# china_sites_20190803.csv
# china_sites_20190804.csv
# china_sites_20190805.csv
# china_sites_20190806.csv
# china_sites_20190807.csv
# china_sites_20190808.csv
# china_sites_20190809.csv
# china_sites_20190810.csv
# china_sites_20190811.csv
# china_sites_20190812.csv
# china_sites_20190813.csv
# china_sites_20190814.csv
# china_sites_20190815.csv
# china_sites_20190816.csv
# china_sites_20190817.csv
# china_sites_20190818.csv
# china_sites_20190819.csv
# china_sites_20190820.csv
# china_sites_20190821.csv
# china_sites_20190822.csv
# china_sites_20190823.csv
# china_sites_20190824.csv
# 'hour'
# china_sites_20190825.csv
# china_sites_20190826.csv
# china_sites_20190827.csv
# china_sites_20190828.csv
# china_sites_20190829.csv
# china_sites_20190830.csv
# china_sites_20190831.csv
# china_sites_20190901.csv
# china_sites_20190902.csv
# china_sites_20190903.csv
# china_sites_20190904.csv
# china_sites_20190905.csv
# china_sites_20190906.csv
# china_sites_20190907.csv
# china_sites_20190908.csv
# china_sites_20190909.csv
# china_sites_20190910.csv
# china_sites_20190911.csv
# china_sites_20190912.csv
# china_sites_20190913.csv
# china_sites_20190914.csv
# china_sites_20190915.csv
# china_sites_20190916.csv
# china_sites_20190917.csv
# china_sites_20190918.csv
# china_sites_20190919.csv
# china_sites_20190920.csv
# china_sites_20190921.csv
# china_sites_20190922.csv
# china_sites_20190923.csv
# china_sites_20190924.csv
# china_sites_20190925.csv
# china_sites_20190926.csv
# china_sites_20190927.csv
# china_sites_20190928.csv
# china_sites_20190929.csv
# china_sites_20190930.csv
# china_sites_20191001.csv
# china_sites_20191002.csv
# china_sites_20191003.csv
# china_sites_20191004.csv
# china_sites_20191005.csv
# china_sites_20191006.csv
# china_sites_20191007.csv
# china_sites_20191008.csv
# china_sites_20191009.csv
# china_sites_20191010.csv
# china_sites_20191011.csv
# china_sites_20191012.csv
# china_sites_20191013.csv
# china_sites_20191014.csv
# china_sites_20191015.csv
# china_sites_20191016.csv
# china_sites_20191017.csv
# china_sites_20191018.csv
# china_sites_20191019.csv
# china_sites_20191020.csv
# china_sites_20191021.csv
# china_sites_20191022.csv
# china_sites_20191023.csv
# china_sites_20191024.csv
# china_sites_20191025.csv
# china_sites_20191026.csv
# china_sites_20191027.csv
# china_sites_20191028.csv
# china_sites_20191029.csv
# china_sites_20191030.csv
# china_sites_20191031.csv
# china_sites_20191101.csv
# china_sites_20191102.csv
# china_sites_20191103.csv
# china_sites_20191104.csv
# china_sites_20191105.csv
# china_sites_20191106.csv
# china_sites_20191107.csv
# china_sites_20191108.csv
# china_sites_20191109.csv
# china_sites_20191110.csv
# china_sites_20191111.csv
# china_sites_20191112.csv
# china_sites_20191113.csv
# china_sites_20191114.csv
# china_sites_20191115.csv
# china_sites_20191116.csv
# china_sites_20191117.csv
# china_sites_20191118.csv
# china_sites_20191119.csv
# china_sites_20191120.csv
# china_sites_20191121.csv
# china_sites_20191122.csv
# china_sites_20191123.csv
# china_sites_20191124.csv
# china_sites_20191125.csv
# china_sites_20191126.csv
# china_sites_20191127.csv
# china_sites_20191128.csv
# china_sites_20191129.csv
# china_sites_20191130.csv
# china_sites_20191201.csv
# china_sites_20191202.csv
# china_sites_20191203.csv
# china_sites_20191204.csv
# china_sites_20191205.csv
# china_sites_20191206.csv
# china_sites_20191207.csv
# china_sites_20191208.csv
# china_sites_20191209.csv
# china_sites_20191210.csv
# china_sites_20191211.csv
# china_sites_20191212.csv
# china_sites_20191213.csv
# china_sites_20191214.csv
# china_sites_20191215.csv
# china_sites_20191216.csv
# china_sites_20191217.csv
# china_sites_20191218.csv
# china_sites_20191219.csv
# china_sites_20191220.csv
# china_sites_20191221.csv
# china_sites_20191222.csv
# china_sites_20191223.csv
# china_sites_20191224.csv
# china_sites_20191225.csv
# china_sites_20191226.csv
# china_sites_20191227.csv
# china_sites_20191228.csv
# china_sites_20191229.csv
# china_sites_20191230.csv
# china_sites_20191231.csv

# %%
# 定义新建表的列名称、站点名称
columns_name = ['date','hour','AQI', 'PM2.5', 'PM10', 'SO2', 'NO2', 'O3', 'O3_8h', 'CO']
sties_name = ['2362A','2363A','2364A','2365A','2366A'] # 循环站点列表

# 定义空白表单：用于全年数据汇总空白表
new_df_allyear = pd.DataFrame(columns = columns_name)

##（获取）date路径文件名单列表
site_file_name_list = os.listdir(path1)

# 定义索引：用于截取正常情况下的数据
index_list = [0] + [2 * i - 1 for i in np.arange(1, 8)] ## list可以直接相加

# %%
for sites in sties_name:  # 循环处理每个站点（site）

    ############## 空白文档：年汇总 ####################
    df_all_years_date = pd.DataFrame(columns=columns_name)

    for file_name in site_file_name_list:  # 循环处理每个文件（file）
        # 打开文件，手动填写路径 path在上文中已经定义 ###################################
        path = os.path.join(path1, file_name)
        df = pd.read_csv(path)

        ################## 空白文档：日汇总 ############
        df_day_date = pd.DataFrame(columns=columns_name)

        for hour in np.arange(0, 24, 1):  # 循环每个小时

            # 获取第‘hour’小时数据索引区间。
            start_num = hour * 15
            end_num = (hour + 1) * 15

            try: # 获取日期数据，可以不使用iloc
                date_value = df['date'].iloc[0]

                # num：每小时有效数据量
                # 具体技巧：df切片hour列→得到series（只包含小时数据）， → 利用==获取bool索引，导入df[]中（或df.loc[]中）切片→特定小时数据df
                # df再切片成ytpe列→得到series（只包含数据类型）→进行count（）计算
                num = df[df['hour'] == hour]['type'].count()

                if num < 15:
                    sub_set = df.iloc[start_num:end_num][['type', sites]].set_index('type')  # type存在空，但是可以被设置为索引

                    # 后面将使用for循环填写empty_series（空白列）
                    empty_series = pd.Series(index=columns_name)

                    for i in columns_name:  # i表示列名称

                        # 将sub_set中相关数据填入到empty_series中
                        # if后的技巧NaN作为索引是，相当于没有索引。（索引NaN表示没有索引）
                        empty_series[i] = sub_set.loc[i][sites] if i in sub_set.index else np.nan
                        # empty_series[i] = sub_set.loc[i, sites] if i in sub_set.index else np.nan

                    # 补齐空series中date和hour
                    empty_series['date'] = date_value
                    empty_series['hour'] = hour

                    # 转置为df结构，用于后续concat, empty_series事实上这里已经有数据了
                    add_df = pd.DataFrame(empty_series).T
                    df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)

                elif num == 15:
                    sub_set = df.iloc[start_num:end_num].iloc[index_list][sites]  # →series

                    # 在df的新的一行填写数据，hour实际上表示第几行。
                    # loc[***] 实际上可以通过列表的形式填写数据内容。
                    df_day_date.loc[hour] = [date_value] + [hour] + sub_set.values.tolist()
            except:
                print(file_name)
                # 补充缺失日期，date有一个小数点是为了格式一致
                missing_date = file_name[-12:-4]
                missing_hours = list(range(24))
                missing_data = {'date': [missing_date] * 24, 'hour': missing_hours}
                missing_df = pd.DataFrame(missing_data)
                df_all_years_date = pd.concat([df_all_years_date, missing_df], ignore_index=True)
                print(file_name)
                break

        df_all_years_date = pd.concat([df_all_years_date, df_day_date], axis=0, ignore_index=True)  # axis = 0表示行方向

    # 保存到 Excel 文件（同一个文件，不同 sheet）
    # 在pd.ExcelWriter方法中，如果原本不存在该文件会自动生成
    # mode='a'表示追加数据模式，engine表示写入引擎
    file_path = f'/mnt/e/_03_data_air/all_2019.xlsx'  ############## 生成文件路径（自定义） ############################################
    try:
        writer = pd.ExcelWriter(file_path, engine='openpyxl', mode='a')

        # index = False表示不写入excel中
        df_all_years_date.to_excel(writer, index=False, sheet_name=f'{sites}')
        writer.close()
    except Exception as e:
        print(f"发生错误: {e}")
        # 处理文件不存在的情况
        df_all_years_date.to_excel(file_path, index=False, sheet_name=f'{sites}')
# Out:
# /tmp/ipykernel_1453/2590854452.py:66: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all_years_date = pd.concat([df_all_years_date, df_day_date], axis=0, ignore_index=True)  # axis = 0表示行方向
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:66: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all_years_date = pd.concat([df_all_years_date, df_day_date], axis=0, ignore_index=True)  # axis = 0表示行方向
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# china_sites_20190824.csv
# china_sites_20190824.csv
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# 发生错误: Sheet '2362A' already exists and if_sheet_exists is set to 'error'.
# /tmp/ipykernel_1453/2590854452.py:66: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all_years_date = pd.concat([df_all_years_date, df_day_date], axis=0, ignore_index=True)  # axis = 0表示行方向
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:66: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all_years_date = pd.concat([df_all_years_date, df_day_date], axis=0, ignore_index=True)  # axis = 0表示行方向
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# china_sites_20190824.csv
# china_sites_20190824.csv
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:66: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all_years_date = pd.concat([df_all_years_date, df_day_date], axis=0, ignore_index=True)  # axis = 0表示行方向
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:66: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all_years_date = pd.concat([df_all_years_date, df_day_date], axis=0, ignore_index=True)  # axis = 0表示行方向
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# china_sites_20190824.csv
# china_sites_20190824.csv
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:66: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all_years_date = pd.concat([df_all_years_date, df_day_date], axis=0, ignore_index=True)  # axis = 0表示行方向
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:66: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all_years_date = pd.concat([df_all_years_date, df_day_date], axis=0, ignore_index=True)  # axis = 0表示行方向
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# china_sites_20190824.csv
# china_sites_20190824.csv
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:66: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all_years_date = pd.concat([df_all_years_date, df_day_date], axis=0, ignore_index=True)  # axis = 0表示行方向
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:66: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all_years_date = pd.concat([df_all_years_date, df_day_date], axis=0, ignore_index=True)  # axis = 0表示行方向
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# china_sites_20190824.csv
# china_sites_20190824.csv
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)
# /tmp/ipykernel_1453/2590854452.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_day_date = pd.concat([df_day_date, add_df], axis=0, ignore_index=True)

# %% [markdown]
# #### 找缺失天数

# %%
list1 = []
list_ab = os.listdir('/mnt/e/_03_data_air/sties/站点_20190101-20191231')
for i in list_ab:
    a = i[-12:-4]
    list1.append(a)

# %%
set1 = pd.date_range('2019-01-01', '2019-12-31', freq='D')
set2 = pd.to_datetime(list1,format = '%Y%m%d')

# %%
missing_dates = set(set1) - set(set2)

# %%
print(missing_dates)
# Out:
# set()
