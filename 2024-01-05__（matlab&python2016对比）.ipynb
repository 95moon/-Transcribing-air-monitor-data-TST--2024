# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
import os

# %% [markdown]
# ### 我做的matlab及python处理后文件校核

# %%
os.listdir( '/mnt/e/_03_data_air')
# Out:
# ['all_2015.xlsx',
#  'all_2016.xlsx',
#  'all_2017.xlsx',
#  'all_2018.xlsx',
#  'all_2019.xlsx',
#  'all_2020.xlsx',
#  'all_2021.xlsx',
#  'all_2022.xlsx',
#  'cities',
#  'gz_all_2015.xlsx',
#  'gz_all_2016.xlsx',
#  'gz_all_2017.xlsx',
#  'gz_all_2018.xlsx',
#  'gz_all_2019.xlsx',
#  'gz_all_2020.xlsx',
#  'gz_all_2021.xlsx',
#  'gz_all_2022.xlsx',
#  'gz_station_2015.xlsx',
#  'gz_station_2016.xlsx',
#  'gz_station_2017.xlsx',
#  'gz_station_2018.xlsx',
#  'gz_station_2019.xlsx',
#  'gz_station_2020.xlsx',
#  'gz_station_2021.xlsx',
#  'gz_station_2022.xlsx',
#  'gz_station_2023.xlsx',
#  'station_2016.xlsx',
#  'station_2019.xlsx',
#  'sties',
#  '修改']

# %%
path_old = '/mnt/e/_03_data_air/gz_all_2016.xlsx' # (自定义)对比文件1 ##########################（old）
path_new = '/mnt/e/_03_data_air/station_2016.xlsx' # (自定义)对比文件2 ##############################（new）
sheets = ['2362A', '2363A', '2364A', '2365A', '2366A']

# %%
### 读取文件
old = pd.read_excel(path_old,sheet_name='2362A')
new = pd.read_excel(path_new,sheet_name='2362A')

### 设置画布和子图
fig, axes = plt.subplots(nrows=1, figsize=(16, 4))

### y轴数据点
yy1 = np.nan_to_num(new['PM2.5']) - np.nan_to_num(old['PM2.5'])
yy2 = np.nan_to_num(new['PM10']) - np.nan_to_num(old['PM10'])
yy3 = np.nan_to_num(new['SO2']) - np.nan_to_num(old['SO2'])
yy4 = np.nan_to_num(new['NO2']) - np.nan_to_num(old['NO2'])
yy5 = np.nan_to_num(new['O3']) - np.nan_to_num(old['O3'])
yy6 = np.nan_to_num(new['O3_8h']) - np.nan_to_num(old['O3_8h'])
yy7 = np.nan_to_num(new['CO']) - np.nan_to_num(old['CO'])

### x轴数据点
x = np.arange(0, 8784)

### 绘制差异线，使用不同颜色
plot1 = axes.plot(x, yy1, linestyle='-', color='red', label='PM2.5 difference')
plot2 = axes.plot(x, yy2, linestyle='-', color='blue', label='PM10 difference')
plot3 = axes.plot(x, yy3, linestyle='-', color='green', label='SO2 difference')
plot4 = axes.plot(x, yy4, linestyle='-', color='orange', label='NO2 difference')
plot5 = axes.plot(x, yy5, linestyle='-', color='purple', label='O3 difference')
plot6 = axes.plot(x, yy6, linestyle='-', color='brown', label='O3_8h difference')
plot7 = axes.plot(x, yy7, linestyle='-', color='pink', label='CO difference')

### 设置标题
axes.set_title('Difference Lines of 2362A')

### x轴和y轴网格线
axes.yaxis.grid(visible=True, color='black', linestyle='--')
axes.xaxis.grid(visible=True, color='gray', linestyle=':')

### x轴刻度和刻度标签设置
axes.set_xticks(np.arange(0, 8800, step=250))
axes.set_xticklabels(np.arange(0, 8800, step=250),rotation = 45, horizontalalignment='right',fontsize=10)

### 设置图例
axes.legend(loc='upper left')

# %%
### 读取文件
old = pd.read_excel(path_old,sheet_name='2363A')
new = pd.read_excel(path_new,sheet_name='2363A')

### 设置画布和子图
fig, axes = plt.subplots(nrows=1, figsize=(16, 4))

### y轴数据点
yy1 = np.nan_to_num(new['PM2.5']) - np.nan_to_num(old['PM2.5'])
yy2 = np.nan_to_num(new['PM10']) - np.nan_to_num(old['PM10'])
yy3 = np.nan_to_num(new['SO2']) - np.nan_to_num(old['SO2'])
yy4 = np.nan_to_num(new['NO2']) - np.nan_to_num(old['NO2'])
yy5 = np.nan_to_num(new['O3']) - np.nan_to_num(old['O3'])
yy6 = np.nan_to_num(new['O3_8h']) - np.nan_to_num(old['O3_8h'])
yy7 = np.nan_to_num(new['CO']) - np.nan_to_num(old['CO'])

### x轴数据点
x = np.arange(0, 8784)

### 绘制差异线，使用不同颜色
plot1 = axes.plot(x, yy1, linestyle='-', color='red', label='PM2.5 difference')
plot2 = axes.plot(x, yy2, linestyle='-', color='blue', label='PM10 difference')
plot3 = axes.plot(x, yy3, linestyle='-', color='green', label='SO2 difference')
plot4 = axes.plot(x, yy4, linestyle='-', color='orange', label='NO2 difference')
plot5 = axes.plot(x, yy5, linestyle='-', color='purple', label='O3 difference')
plot6 = axes.plot(x, yy6, linestyle='-', color='brown', label='O3_8h difference')
plot7 = axes.plot(x, yy7, linestyle='-', color='pink', label='CO difference')

### 设置标题
axes.set_title('Difference Lines of 2363A')

### x轴和y轴网格线
axes.yaxis.grid(visible=True, color='black', linestyle='--')
axes.xaxis.grid(visible=True, color='gray', linestyle=':')

### x轴刻度和刻度标签设置
axes.set_xticks(np.arange(0, 8800, step=250))
axes.set_xticklabels(np.arange(0, 8800, step=250),rotation = 45, horizontalalignment='right',fontsize=10)

### 设置图例
axes.legend(loc='upper left')

# %%
### 读取文件
old = pd.read_excel(path_old,sheet_name='2364A')
new = pd.read_excel(path_new,sheet_name='2364A')

### 设置画布和子图
fig, axes = plt.subplots(nrows=1, figsize=(16, 4))

### y轴数据点
yy1 = np.nan_to_num(new['PM2.5']) - np.nan_to_num(old['PM2.5'])
yy2 = np.nan_to_num(new['PM10']) - np.nan_to_num(old['PM10'])
yy3 = np.nan_to_num(new['SO2']) - np.nan_to_num(old['SO2'])
yy4 = np.nan_to_num(new['NO2']) - np.nan_to_num(old['NO2'])
yy5 = np.nan_to_num(new['O3']) - np.nan_to_num(old['O3'])
yy6 = np.nan_to_num(new['O3_8h']) - np.nan_to_num(old['O3_8h'])
yy7 = np.nan_to_num(new['CO']) - np.nan_to_num(old['CO'])

### x轴数据点
x = np.arange(0, 8784)

### 绘制差异线，使用不同颜色
plot1 = axes.plot(x, yy1, linestyle='-', color='red', label='PM2.5 difference')
plot2 = axes.plot(x, yy2, linestyle='-', color='blue', label='PM10 difference')
plot3 = axes.plot(x, yy3, linestyle='-', color='green', label='SO2 difference')
plot4 = axes.plot(x, yy4, linestyle='-', color='orange', label='NO2 difference')
plot5 = axes.plot(x, yy5, linestyle='-', color='purple', label='O3 difference')
plot6 = axes.plot(x, yy6, linestyle='-', color='brown', label='O3_8h difference')
plot7 = axes.plot(x, yy7, linestyle='-', color='pink', label='CO difference')

### 设置标题
axes.set_title('Difference Lines of 2364A')

### x轴和y轴网格线
axes.yaxis.grid(visible=True, color='black', linestyle='--')
axes.xaxis.grid(visible=True, color='gray', linestyle=':')

### x轴刻度和刻度标签设置
axes.set_xticks(np.arange(0, 8800, step=250))
axes.set_xticklabels(np.arange(0, 8800, step=250),rotation = 45, horizontalalignment='right',fontsize=10)

### 设置图例
axes.legend(loc='upper left')

# %%
### 读取文件
old = pd.read_excel(path_old,sheet_name='2365A')
new = pd.read_excel(path_new,sheet_name='2365A')

### 设置画布和子图
fig, axes = plt.subplots(nrows=1, figsize=(16, 4))

### y轴数据点
yy1 = np.nan_to_num(new['PM2.5']) - np.nan_to_num(old['PM2.5'])
yy2 = np.nan_to_num(new['PM10']) - np.nan_to_num(old['PM10'])
yy3 = np.nan_to_num(new['SO2']) - np.nan_to_num(old['SO2'])
yy4 = np.nan_to_num(new['NO2']) - np.nan_to_num(old['NO2'])
yy5 = np.nan_to_num(new['O3']) - np.nan_to_num(old['O3'])
yy6 = np.nan_to_num(new['O3_8h']) - np.nan_to_num(old['O3_8h'])
yy7 = np.nan_to_num(new['CO']) - np.nan_to_num(old['CO'])

### x轴数据点
x = np.arange(0, 8784)

### 绘制差异线，使用不同颜色
plot1 = axes.plot(x, yy1, linestyle='-', color='red', label='PM2.5 difference')
plot2 = axes.plot(x, yy2, linestyle='-', color='blue', label='PM10 difference')
plot3 = axes.plot(x, yy3, linestyle='-', color='green', label='SO2 difference')
plot4 = axes.plot(x, yy4, linestyle='-', color='orange', label='NO2 difference')
plot5 = axes.plot(x, yy5, linestyle='-', color='purple', label='O3 difference')
plot6 = axes.plot(x, yy6, linestyle='-', color='brown', label='O3_8h difference')
plot7 = axes.plot(x, yy7, linestyle='-', color='pink', label='CO difference')

### 设置标题
axes.set_title('Difference Lines of 2365A')

### x轴和y轴网格线
axes.yaxis.grid(visible=True, color='black', linestyle='--')
axes.xaxis.grid(visible=True, color='gray', linestyle=':')

### x轴刻度和刻度标签设置
axes.set_xticks(np.arange(0, 8800, step=250))
axes.set_xticklabels(np.arange(0, 8800, step=250),rotation = 45, horizontalalignment='right',fontsize=10)

### 设置图例
axes.legend(loc='upper left')

# %%
### 读取文件
old = pd.read_excel(path_old,sheet_name='2366A')
new = pd.read_excel(path_new,sheet_name='2366A')

### 设置画布和子图
fig, axes = plt.subplots(nrows=1, figsize=(16, 4))

### y轴数据点
yy1 = np.nan_to_num(new['PM2.5']) - np.nan_to_num(old['PM2.5'])
yy2 = np.nan_to_num(new['PM10']) - np.nan_to_num(old['PM10'])
yy3 = np.nan_to_num(new['SO2']) - np.nan_to_num(old['SO2'])
yy4 = np.nan_to_num(new['NO2']) - np.nan_to_num(old['NO2'])
yy5 = np.nan_to_num(new['O3']) - np.nan_to_num(old['O3'])
yy6 = np.nan_to_num(new['O3_8h']) - np.nan_to_num(old['O3_8h'])
yy7 = np.nan_to_num(new['CO']) - np.nan_to_num(old['CO'])

### x轴数据点
x = np.arange(0, 8784)

### 绘制差异线，使用不同颜色
plot1 = axes.plot(x, yy1, linestyle='-', color='red', label='PM2.5 difference')
plot2 = axes.plot(x, yy2, linestyle='-', color='blue', label='PM10 difference')
plot3 = axes.plot(x, yy3, linestyle='-', color='green', label='SO2 difference')
plot4 = axes.plot(x, yy4, linestyle='-', color='orange', label='NO2 difference')
plot5 = axes.plot(x, yy5, linestyle='-', color='purple', label='O3 difference')
plot6 = axes.plot(x, yy6, linestyle='-', color='brown', label='O3_8h difference')
plot7 = axes.plot(x, yy7, linestyle='-', color='pink', label='CO difference')

### 设置标题
axes.set_title('Difference Lines of 2366A')

### x轴和y轴网格线
axes.yaxis.grid(visible=True, color='black', linestyle='--')
axes.xaxis.grid(visible=True, color='gray', linestyle=':')

### x轴刻度和刻度标签设置
axes.set_xticks(np.arange(0, 8800, step=250))
axes.set_xticklabels(np.arange(0, 8800, step=250),rotation = 45, horizontalalignment='right',fontsize=10)

### 设置图例
axes.legend(loc='upper left')

# %%
total = 0
# 初始化字典用于存储计数
count_dict = {}
for sheet in sheets:
    old_df = pd.read_excel(path_old, sheet_name=sheet)
    new_df = pd.read_excel(path_new, sheet_name=sheet)
    col_name = ['PM2.5', 'PM10', 'SO2', 'NO2', 'O3', 'O3_8h', 'CO'] # new_df.columns[3:-3]  # 获取对比列名称（可以直接输入）

    for col in col_name:
        for row in old_df.index:
            a = old_df[col][row]
            b = new_df[col][row]
            c = old_df[col][row]
            d = new_df[col][row]

            if not (np.isnan(a) and np.isnan(b)) and a != b:
                print(f'在sheet {sheet}，对比文件1中 {c} 和对比文件2中 {d} 不同，在excel表行 {row + 2}，列 {col}。')
                total += 1

                # 根据站点和变量类型构建字典的键
                key = f'{sheet}_{col}'

                # 判断键是否存在于字典中，如果不存在则初始化为0
                count_dict[key] = count_dict.get(key, 0) + 1

# 输出每个站点和变量类型的不同数量
for key, value in count_dict.items():
    print(f'{key} 有 {value} 处不同')
# 输出总的不同数量
print(f'一共有 {total} 处不同')
# Out:
# 在sheet 2362A，对比文件1中 22.0 和对比文件2中 nan 不同，在excel表行 5138，列 PM2.5。
# 在sheet 2362A，对比文件1中 23.0 和对比文件2中 nan 不同，在excel表行 5139，列 PM2.5。
# 在sheet 2362A，对比文件1中 20.0 和对比文件2中 nan 不同，在excel表行 5140，列 PM2.5。
# 在sheet 2362A，对比文件1中 16.0 和对比文件2中 nan 不同，在excel表行 5141，列 PM2.5。
# 在sheet 2362A，对比文件1中 10.0 和对比文件2中 nan 不同，在excel表行 5142，列 PM2.5。
# 在sheet 2362A，对比文件1中 12.0 和对比文件2中 nan 不同，在excel表行 5143，列 PM2.5。
# 在sheet 2362A，对比文件1中 12.0 和对比文件2中 nan 不同，在excel表行 5144，列 PM2.5。
# 在sheet 2362A，对比文件1中 12.0 和对比文件2中 nan 不同，在excel表行 5145，列 PM2.5。
# 在sheet 2362A，对比文件1中 18.0 和对比文件2中 nan 不同，在excel表行 5149，列 PM2.5。
# 在sheet 2362A，对比文件1中 18.0 和对比文件2中 nan 不同，在excel表行 5150，列 PM2.5。
# 在sheet 2362A，对比文件1中 20.0 和对比文件2中 nan 不同，在excel表行 5151，列 PM2.5。
# 在sheet 2362A，对比文件1中 30.0 和对比文件2中 nan 不同，在excel表行 5138，列 PM10。
# 在sheet 2362A，对比文件1中 26.0 和对比文件2中 nan 不同，在excel表行 5139，列 PM10。
# 在sheet 2362A，对比文件1中 27.0 和对比文件2中 nan 不同，在excel表行 5140，列 PM10。
# 在sheet 2362A，对比文件1中 22.0 和对比文件2中 nan 不同，在excel表行 5141，列 PM10。
# 在sheet 2362A，对比文件1中 20.0 和对比文件2中 nan 不同，在excel表行 5142，列 PM10。
# 在sheet 2362A，对比文件1中 15.0 和对比文件2中 nan 不同，在excel表行 5143，列 PM10。
# 在sheet 2362A，对比文件1中 20.0 和对比文件2中 nan 不同，在excel表行 5144，列 PM10。
# 在sheet 2362A，对比文件1中 16.0 和对比文件2中 nan 不同，在excel表行 5145，列 PM10。
# 在sheet 2362A，对比文件1中 24.0 和对比文件2中 nan 不同，在excel表行 5149，列 PM10。
# 在sheet 2362A，对比文件1中 26.0 和对比文件2中 nan 不同，在excel表行 5150，列 PM10。
# 在sheet 2362A，对比文件1中 7.0 和对比文件2中 nan 不同，在excel表行 5138，列 SO2。
# 在sheet 2362A，对比文件1中 8.0 和对比文件2中 nan 不同，在excel表行 5139，列 SO2。
# 在sheet 2362A，对比文件1中 9.0 和对比文件2中 nan 不同，在excel表行 5140，列 SO2。
# 在sheet 2362A，对比文件1中 6.0 和对比文件2中 nan 不同，在excel表行 5141，列 SO2。
# 在sheet 2362A，对比文件1中 6.0 和对比文件2中 nan 不同，在excel表行 5142，列 SO2。
# 在sheet 2362A，对比文件1中 8.0 和对比文件2中 nan 不同，在excel表行 5143，列 SO2。
# 在sheet 2362A，对比文件1中 11.0 和对比文件2中 nan 不同，在excel表行 5144，列 SO2。
# 在sheet 2362A，对比文件1中 10.0 和对比文件2中 nan 不同，在excel表行 5145，列 SO2。
# 在sheet 2362A，对比文件1中 7.0 和对比文件2中 nan 不同，在excel表行 5149，列 SO2。
# 在sheet 2362A，对比文件1中 4.0 和对比文件2中 nan 不同，在excel表行 5150，列 SO2。
# 在sheet 2362A，对比文件1中 8.0 和对比文件2中 nan 不同，在excel表行 5138，列 NO2。
# 在sheet 2362A，对比文件1中 9.0 和对比文件2中 nan 不同，在excel表行 5139，列 NO2。
# 在sheet 2362A，对比文件1中 8.0 和对比文件2中 nan 不同，在excel表行 5140，列 NO2。
# 在sheet 2362A，对比文件1中 7.0 和对比文件2中 nan 不同，在excel表行 5141，列 NO2。
# 在sheet 2362A，对比文件1中 9.0 和对比文件2中 nan 不同，在excel表行 5142，列 NO2。
# 在sheet 2362A，对比文件1中 8.0 和对比文件2中 nan 不同，在excel表行 5143，列 NO2。
# 在sheet 2362A，对比文件1中 8.0 和对比文件2中 nan 不同，在excel表行 5144，列 NO2。
# 在sheet 2362A，对比文件1中 8.0 和对比文件2中 nan 不同，在excel表行 5145，列 NO2。
# 在sheet 2362A，对比文件1中 9.0 和对比文件2中 nan 不同，在excel表行 5149，列 NO2。
# 在sheet 2362A，对比文件1中 8.0 和对比文件2中 nan 不同，在excel表行 5150，列 NO2。
# 在sheet 2362A，对比文件1中 20.0 和对比文件2中 nan 不同，在excel表行 5138，列 O3。
# 在sheet 2362A，对比文件1中 28.0 和对比文件2中 nan 不同，在excel表行 5139，列 O3。
# 在sheet 2362A，对比文件1中 30.0 和对比文件2中 nan 不同，在excel表行 5140，列 O3。
# 在sheet 2362A，对比文件1中 31.0 和对比文件2中 nan 不同，在excel表行 5141，列 O3。
# 在sheet 2362A，对比文件1中 31.0 和对比文件2中 nan 不同，在excel表行 5142，列 O3。
# 在sheet 2362A，对比文件1中 31.0 和对比文件2中 nan 不同，在excel表行 5143，列 O3。
# 在sheet 2362A，对比文件1中 32.0 和对比文件2中 nan 不同，在excel表行 5144，列 O3。
# 在sheet 2362A，对比文件1中 29.0 和对比文件2中 nan 不同，在excel表行 5145，列 O3。
# 在sheet 2362A，对比文件1中 28.0 和对比文件2中 nan 不同，在excel表行 5149，列 O3。
# 在sheet 2362A，对比文件1中 30.0 和对比文件2中 nan 不同，在excel表行 5150，列 O3。
# 在sheet 2362A，对比文件1中 35.0 和对比文件2中 nan 不同，在excel表行 5138，列 O3_8h。
# 在sheet 2362A，对比文件1中 28.0 和对比文件2中 nan 不同，在excel表行 5139，列 O3_8h。
# 在sheet 2362A，对比文件1中 29.0 和对比文件2中 nan 不同，在excel表行 5140，列 O3_8h。
# 在sheet 2362A，对比文件1中 30.0 和对比文件2中 nan 不同，在excel表行 5141，列 O3_8h。
# 在sheet 2362A，对比文件1中 30.0 和对比文件2中 nan 不同，在excel表行 5142，列 O3_8h。
# 在sheet 2362A，对比文件1中 30.0 和对比文件2中 nan 不同，在excel表行 5143，列 O3_8h。
# 在sheet 2362A，对比文件1中 30.0 和对比文件2中 nan 不同，在excel表行 5144，列 O3_8h。
# 在sheet 2362A，对比文件1中 30.0 和对比文件2中 nan 不同，在excel表行 5145，列 O3_8h。
# 在sheet 2362A，对比文件1中 28.0 和对比文件2中 nan 不同，在excel表行 5149，列 O3_8h。
# 在sheet 2362A，对比文件1中 28.0 和对比文件2中 nan 不同，在excel表行 5150，列 O3_8h。
# 在sheet 2362A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5138，列 CO。
# 在sheet 2362A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5139，列 CO。
# 在sheet 2362A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5140，列 CO。
# 在sheet 2362A，对比文件1中 0.8 和对比文件2中 nan 不同，在excel表行 5141，列 CO。
# 在sheet 2362A，对比文件1中 0.8 和对比文件2中 nan 不同，在excel表行 5142，列 CO。
# 在sheet 2362A，对比文件1中 0.8 和对比文件2中 nan 不同，在excel表行 5143，列 CO。
# 在sheet 2362A，对比文件1中 0.8 和对比文件2中 nan 不同，在excel表行 5144，列 CO。
# 在sheet 2362A，对比文件1中 0.8 和对比文件2中 nan 不同，在excel表行 5145，列 CO。
# 在sheet 2362A，对比文件1中 0.8 和对比文件2中 nan 不同，在excel表行 5149，列 CO。
# 在sheet 2362A，对比文件1中 0.8 和对比文件2中 nan 不同，在excel表行 5150，列 CO。
# 在sheet 2363A，对比文件1中 16.0 和对比文件2中 nan 不同，在excel表行 5138，列 PM2.5。
# 在sheet 2363A，对比文件1中 17.0 和对比文件2中 nan 不同，在excel表行 5139，列 PM2.5。
# 在sheet 2363A，对比文件1中 16.0 和对比文件2中 nan 不同，在excel表行 5140，列 PM2.5。
# 在sheet 2363A，对比文件1中 15.0 和对比文件2中 nan 不同，在excel表行 5141，列 PM2.5。
# 在sheet 2363A，对比文件1中 14.0 和对比文件2中 nan 不同，在excel表行 5142，列 PM2.5。
# 在sheet 2363A，对比文件1中 13.0 和对比文件2中 nan 不同，在excel表行 5143，列 PM2.5。
# 在sheet 2363A，对比文件1中 11.0 和对比文件2中 nan 不同，在excel表行 5144，列 PM2.5。
# 在sheet 2363A，对比文件1中 12.0 和对比文件2中 nan 不同，在excel表行 5145，列 PM2.5。
# 在sheet 2363A，对比文件1中 20.0 和对比文件2中 nan 不同，在excel表行 5149，列 PM2.5。
# 在sheet 2363A，对比文件1中 22.0 和对比文件2中 nan 不同，在excel表行 5150，列 PM2.5。
# 在sheet 2363A，对比文件1中 21.0 和对比文件2中 nan 不同，在excel表行 5151，列 PM2.5。
# 在sheet 2363A，对比文件1中 29.0 和对比文件2中 nan 不同，在excel表行 5138，列 PM10。
# 在sheet 2363A，对比文件1中 32.0 和对比文件2中 nan 不同，在excel表行 5139，列 PM10。
# 在sheet 2363A，对比文件1中 32.0 和对比文件2中 nan 不同，在excel表行 5140，列 PM10。
# 在sheet 2363A，对比文件1中 31.0 和对比文件2中 nan 不同，在excel表行 5141，列 PM10。
# 在sheet 2363A，对比文件1中 30.0 和对比文件2中 nan 不同，在excel表行 5142，列 PM10。
# 在sheet 2363A，对比文件1中 23.0 和对比文件2中 nan 不同，在excel表行 5143，列 PM10。
# 在sheet 2363A，对比文件1中 21.0 和对比文件2中 nan 不同，在excel表行 5144，列 PM10。
# 在sheet 2363A，对比文件1中 19.0 和对比文件2中 nan 不同，在excel表行 5145，列 PM10。
# 在sheet 2363A，对比文件1中 31.0 和对比文件2中 nan 不同，在excel表行 5149，列 PM10。
# 在sheet 2363A，对比文件1中 35.0 和对比文件2中 nan 不同，在excel表行 5150，列 PM10。
# 在sheet 2363A，对比文件1中 18.0 和对比文件2中 nan 不同，在excel表行 5138，列 SO2。
# 在sheet 2363A，对比文件1中 18.0 和对比文件2中 nan 不同，在excel表行 5139，列 SO2。
# 在sheet 2363A，对比文件1中 17.0 和对比文件2中 nan 不同，在excel表行 5140，列 SO2。
# 在sheet 2363A，对比文件1中 21.0 和对比文件2中 nan 不同，在excel表行 5141，列 SO2。
# 在sheet 2363A，对比文件1中 29.0 和对比文件2中 nan 不同，在excel表行 5142，列 SO2。
# 在sheet 2363A，对比文件1中 40.0 和对比文件2中 nan 不同，在excel表行 5143，列 SO2。
# 在sheet 2363A，对比文件1中 15.0 和对比文件2中 nan 不同，在excel表行 5144，列 SO2。
# 在sheet 2363A，对比文件1中 18.0 和对比文件2中 nan 不同，在excel表行 5145，列 SO2。
# 在sheet 2363A，对比文件1中 18.0 和对比文件2中 nan 不同，在excel表行 5149，列 SO2。
# 在sheet 2363A，对比文件1中 16.0 和对比文件2中 nan 不同，在excel表行 5150，列 SO2。
# 在sheet 2363A，对比文件1中 nan 和对比文件2中 175.0 不同，在excel表行 8770，列 SO2。
# 在sheet 2363A，对比文件1中 nan 和对比文件2中 180.0 不同，在excel表行 8771，列 SO2。
# 在sheet 2363A，对比文件1中 nan 和对比文件2中 149.0 不同，在excel表行 8772，列 SO2。
# 在sheet 2363A，对比文件1中 15.0 和对比文件2中 nan 不同，在excel表行 5138，列 NO2。
# 在sheet 2363A，对比文件1中 12.0 和对比文件2中 nan 不同，在excel表行 5139，列 NO2。
# 在sheet 2363A，对比文件1中 12.0 和对比文件2中 nan 不同，在excel表行 5140，列 NO2。
# 在sheet 2363A，对比文件1中 9.0 和对比文件2中 nan 不同，在excel表行 5141，列 NO2。
# 在sheet 2363A，对比文件1中 7.0 和对比文件2中 nan 不同，在excel表行 5142，列 NO2。
# 在sheet 2363A，对比文件1中 6.0 和对比文件2中 nan 不同，在excel表行 5143，列 NO2。
# 在sheet 2363A，对比文件1中 8.0 和对比文件2中 nan 不同，在excel表行 5144，列 NO2。
# 在sheet 2363A，对比文件1中 11.0 和对比文件2中 nan 不同，在excel表行 5145，列 NO2。
# 在sheet 2363A，对比文件1中 17.0 和对比文件2中 nan 不同，在excel表行 5149，列 NO2。
# 在sheet 2363A，对比文件1中 12.0 和对比文件2中 nan 不同，在excel表行 5150，列 NO2。
# 在sheet 2363A，对比文件1中 24.0 和对比文件2中 nan 不同，在excel表行 5138，列 O3。
# 在sheet 2363A，对比文件1中 25.0 和对比文件2中 nan 不同，在excel表行 5139，列 O3。
# 在sheet 2363A，对比文件1中 24.0 和对比文件2中 nan 不同，在excel表行 5140，列 O3。
# 在sheet 2363A，对比文件1中 29.0 和对比文件2中 nan 不同，在excel表行 5141，列 O3。
# 在sheet 2363A，对比文件1中 33.0 和对比文件2中 nan 不同，在excel表行 5142，列 O3。
# 在sheet 2363A，对比文件1中 32.0 和对比文件2中 nan 不同，在excel表行 5143，列 O3。
# 在sheet 2363A，对比文件1中 33.0 和对比文件2中 nan 不同，在excel表行 5144，列 O3。
# 在sheet 2363A，对比文件1中 29.0 和对比文件2中 nan 不同，在excel表行 5145，列 O3。
# 在sheet 2363A，对比文件1中 25.0 和对比文件2中 nan 不同，在excel表行 5149，列 O3。
# 在sheet 2363A，对比文件1中 33.0 和对比文件2中 nan 不同，在excel表行 5150，列 O3。
# 在sheet 2363A，对比文件1中 37.0 和对比文件2中 nan 不同，在excel表行 5138，列 O3_8h。
# 在sheet 2363A，对比文件1中 25.0 和对比文件2中 nan 不同，在excel表行 5139，列 O3_8h。
# 在sheet 2363A，对比文件1中 24.0 和对比文件2中 nan 不同，在excel表行 5140，列 O3_8h。
# 在sheet 2363A，对比文件1中 26.0 和对比文件2中 nan 不同，在excel表行 5141，列 O3_8h。
# 在sheet 2363A，对比文件1中 28.0 和对比文件2中 nan 不同，在excel表行 5142，列 O3_8h。
# 在sheet 2363A，对比文件1中 29.0 和对比文件2中 nan 不同，在excel表行 5143，列 O3_8h。
# 在sheet 2363A，对比文件1中 29.0 和对比文件2中 nan 不同，在excel表行 5144，列 O3_8h。
# 在sheet 2363A，对比文件1中 29.0 和对比文件2中 nan 不同，在excel表行 5145，列 O3_8h。
# 在sheet 2363A，对比文件1中 27.0 和对比文件2中 nan 不同，在excel表行 5149，列 O3_8h。
# 在sheet 2363A，对比文件1中 27.0 和对比文件2中 nan 不同，在excel表行 5150，列 O3_8h。
# 在sheet 2363A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5138，列 CO。
# 在sheet 2363A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5139，列 CO。
# 在sheet 2363A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5140，列 CO。
# 在sheet 2363A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5141，列 CO。
# 在sheet 2363A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5142，列 CO。
# 在sheet 2363A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5143，列 CO。
# 在sheet 2363A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5144，列 CO。
# 在sheet 2363A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5145，列 CO。
# 在sheet 2363A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5149，列 CO。
# 在sheet 2363A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5150，列 CO。
# 在sheet 2364A，对比文件1中 12.0 和对比文件2中 nan 不同，在excel表行 5138，列 PM2.5。
# 在sheet 2364A，对比文件1中 14.0 和对比文件2中 nan 不同，在excel表行 5139，列 PM2.5。
# 在sheet 2364A，对比文件1中 15.0 和对比文件2中 nan 不同，在excel表行 5140，列 PM2.5。
# 在sheet 2364A，对比文件1中 13.0 和对比文件2中 nan 不同，在excel表行 5141，列 PM2.5。
# 在sheet 2364A，对比文件1中 14.0 和对比文件2中 nan 不同，在excel表行 5142，列 PM2.5。
# 在sheet 2364A，对比文件1中 14.0 和对比文件2中 nan 不同，在excel表行 5143，列 PM2.5。
# 在sheet 2364A，对比文件1中 10.0 和对比文件2中 nan 不同，在excel表行 5144，列 PM2.5。
# 在sheet 2364A，对比文件1中 8.0 和对比文件2中 nan 不同，在excel表行 5145，列 PM2.5。
# 在sheet 2364A，对比文件1中 14.0 和对比文件2中 nan 不同，在excel表行 5149，列 PM2.5。
# 在sheet 2364A，对比文件1中 19.0 和对比文件2中 nan 不同，在excel表行 5150，列 PM2.5。
# 在sheet 2364A，对比文件1中 17.0 和对比文件2中 nan 不同，在excel表行 5151，列 PM2.5。
# 在sheet 2364A，对比文件1中 35.0 和对比文件2中 nan 不同，在excel表行 5138，列 PM10。
# 在sheet 2364A，对比文件1中 39.0 和对比文件2中 nan 不同，在excel表行 5139，列 PM10。
# 在sheet 2364A，对比文件1中 36.0 和对比文件2中 nan 不同，在excel表行 5140，列 PM10。
# 在sheet 2364A，对比文件1中 37.0 和对比文件2中 nan 不同，在excel表行 5141，列 PM10。
# 在sheet 2364A，对比文件1中 33.0 和对比文件2中 nan 不同，在excel表行 5142，列 PM10。
# 在sheet 2364A，对比文件1中 26.0 和对比文件2中 nan 不同，在excel表行 5143，列 PM10。
# 在sheet 2364A，对比文件1中 21.0 和对比文件2中 nan 不同，在excel表行 5144，列 PM10。
# 在sheet 2364A，对比文件1中 16.0 和对比文件2中 nan 不同，在excel表行 5145，列 PM10。
# 在sheet 2364A，对比文件1中 31.0 和对比文件2中 nan 不同，在excel表行 5149，列 PM10。
# 在sheet 2364A，对比文件1中 33.0 和对比文件2中 nan 不同，在excel表行 5150，列 PM10。
# 在sheet 2364A，对比文件1中 9.0 和对比文件2中 nan 不同，在excel表行 5138，列 SO2。
# 在sheet 2364A，对比文件1中 13.0 和对比文件2中 nan 不同，在excel表行 5139，列 SO2。
# 在sheet 2364A，对比文件1中 10.0 和对比文件2中 nan 不同，在excel表行 5140，列 SO2。
# 在sheet 2364A，对比文件1中 8.0 和对比文件2中 nan 不同，在excel表行 5141，列 SO2。
# 在sheet 2364A，对比文件1中 6.0 和对比文件2中 nan 不同，在excel表行 5142，列 SO2。
# 在sheet 2364A，对比文件1中 7.0 和对比文件2中 nan 不同，在excel表行 5143，列 SO2。
# 在sheet 2364A，对比文件1中 9.0 和对比文件2中 nan 不同，在excel表行 5144，列 SO2。
# 在sheet 2364A，对比文件1中 8.0 和对比文件2中 nan 不同，在excel表行 5145，列 SO2。
# 在sheet 2364A，对比文件1中 7.0 和对比文件2中 nan 不同，在excel表行 5149，列 SO2。
# 在sheet 2364A，对比文件1中 7.0 和对比文件2中 nan 不同，在excel表行 5150，列 SO2。
# 在sheet 2364A，对比文件1中 nan 和对比文件2中 111.0 不同，在excel表行 8763，列 SO2。
# 在sheet 2364A，对比文件1中 15.0 和对比文件2中 nan 不同，在excel表行 5138，列 NO2。
# 在sheet 2364A，对比文件1中 10.0 和对比文件2中 nan 不同，在excel表行 5139，列 NO2。
# 在sheet 2364A，对比文件1中 6.0 和对比文件2中 nan 不同，在excel表行 5140，列 NO2。
# 在sheet 2364A，对比文件1中 5.0 和对比文件2中 nan 不同，在excel表行 5141，列 NO2。
# 在sheet 2364A，对比文件1中 2.0 和对比文件2中 nan 不同，在excel表行 5142，列 NO2。
# 在sheet 2364A，对比文件1中 4.0 和对比文件2中 nan 不同，在excel表行 5143，列 NO2。
# 在sheet 2364A，对比文件1中 6.0 和对比文件2中 nan 不同，在excel表行 5144，列 NO2。
# 在sheet 2364A，对比文件1中 9.0 和对比文件2中 nan 不同，在excel表行 5145，列 NO2。
# 在sheet 2364A，对比文件1中 17.0 和对比文件2中 nan 不同，在excel表行 5149，列 NO2。
# 在sheet 2364A，对比文件1中 12.0 和对比文件2中 nan 不同，在excel表行 5150，列 NO2。
# 在sheet 2364A，对比文件1中 30.0 和对比文件2中 nan 不同，在excel表行 5138，列 O3。
# 在sheet 2364A，对比文件1中 33.0 和对比文件2中 nan 不同，在excel表行 5139，列 O3。
# 在sheet 2364A，对比文件1中 35.0 和对比文件2中 nan 不同，在excel表行 5140，列 O3。
# 在sheet 2364A，对比文件1中 39.0 和对比文件2中 nan 不同，在excel表行 5141，列 O3。
# 在sheet 2364A，对比文件1中 43.0 和对比文件2中 nan 不同，在excel表行 5142，列 O3。
# 在sheet 2364A，对比文件1中 40.0 和对比文件2中 nan 不同，在excel表行 5143，列 O3。
# 在sheet 2364A，对比文件1中 39.0 和对比文件2中 nan 不同，在excel表行 5144，列 O3。
# 在sheet 2364A，对比文件1中 37.0 和对比文件2中 nan 不同，在excel表行 5145，列 O3。
# 在sheet 2364A，对比文件1中 32.0 和对比文件2中 nan 不同，在excel表行 5149，列 O3。
# 在sheet 2364A，对比文件1中 42.0 和对比文件2中 nan 不同，在excel表行 5150，列 O3。
# 在sheet 2364A，对比文件1中 nan 和对比文件2中 203.0 不同，在excel表行 8779，列 O3。
# 在sheet 2364A，对比文件1中 nan 和对比文件2中 218.0 不同，在excel表行 8781，列 O3。
# 在sheet 2364A，对比文件1中 41.0 和对比文件2中 nan 不同，在excel表行 5138，列 O3_8h。
# 在sheet 2364A，对比文件1中 33.0 和对比文件2中 nan 不同，在excel表行 5139，列 O3_8h。
# 在sheet 2364A，对比文件1中 34.0 和对比文件2中 nan 不同，在excel表行 5140，列 O3_8h。
# 在sheet 2364A，对比文件1中 36.0 和对比文件2中 nan 不同，在excel表行 5141，列 O3_8h。
# 在sheet 2364A，对比文件1中 38.0 和对比文件2中 nan 不同，在excel表行 5142，列 O3_8h。
# 在sheet 2364A，对比文件1中 38.0 和对比文件2中 nan 不同，在excel表行 5143，列 O3_8h。
# 在sheet 2364A，对比文件1中 38.0 和对比文件2中 nan 不同，在excel表行 5144，列 O3_8h。
# 在sheet 2364A，对比文件1中 38.0 和对比文件2中 nan 不同，在excel表行 5145，列 O3_8h。
# 在sheet 2364A，对比文件1中 35.0 和对比文件2中 nan 不同，在excel表行 5149，列 O3_8h。
# 在sheet 2364A，对比文件1中 35.0 和对比文件2中 nan 不同，在excel表行 5150，列 O3_8h。
# 在sheet 2364A，对比文件1中 nan 和对比文件2中 2.953 不同，在excel表行 1874，列 CO。
# 在sheet 2364A，对比文件1中 1.3 和对比文件2中 nan 不同，在excel表行 5138，列 CO。
# 在sheet 2364A，对比文件1中 1.3 和对比文件2中 nan 不同，在excel表行 5139，列 CO。
# 在sheet 2364A，对比文件1中 1.2 和对比文件2中 nan 不同，在excel表行 5140，列 CO。
# 在sheet 2364A，对比文件1中 1.2 和对比文件2中 nan 不同，在excel表行 5141，列 CO。
# 在sheet 2364A，对比文件1中 1.2 和对比文件2中 nan 不同，在excel表行 5142，列 CO。
# 在sheet 2364A，对比文件1中 1.2 和对比文件2中 nan 不同，在excel表行 5143，列 CO。
# 在sheet 2364A，对比文件1中 1.2 和对比文件2中 nan 不同，在excel表行 5144，列 CO。
# 在sheet 2364A，对比文件1中 1.3 和对比文件2中 nan 不同，在excel表行 5145，列 CO。
# 在sheet 2364A，对比文件1中 1.3 和对比文件2中 nan 不同，在excel表行 5149，列 CO。
# 在sheet 2364A，对比文件1中 1.3 和对比文件2中 nan 不同，在excel表行 5150，列 CO。
# 在sheet 2365A，对比文件1中 21.0 和对比文件2中 nan 不同，在excel表行 5138，列 PM2.5。
# 在sheet 2365A，对比文件1中 23.0 和对比文件2中 nan 不同，在excel表行 5139，列 PM2.5。
# 在sheet 2365A，对比文件1中 18.0 和对比文件2中 nan 不同，在excel表行 5140，列 PM2.5。
# 在sheet 2365A，对比文件1中 20.0 和对比文件2中 nan 不同，在excel表行 5141，列 PM2.5。
# 在sheet 2365A，对比文件1中 20.0 和对比文件2中 nan 不同，在excel表行 5142，列 PM2.5。
# 在sheet 2365A，对比文件1中 19.0 和对比文件2中 nan 不同，在excel表行 5143，列 PM2.5。
# 在sheet 2365A，对比文件1中 14.0 和对比文件2中 nan 不同，在excel表行 5144，列 PM2.5。
# 在sheet 2365A，对比文件1中 11.0 和对比文件2中 nan 不同，在excel表行 5145，列 PM2.5。
# 在sheet 2365A，对比文件1中 18.0 和对比文件2中 nan 不同，在excel表行 5149，列 PM2.5。
# 在sheet 2365A，对比文件1中 17.0 和对比文件2中 nan 不同，在excel表行 5150，列 PM2.5。
# 在sheet 2365A，对比文件1中 17.0 和对比文件2中 nan 不同，在excel表行 5151，列 PM2.5。
# 在sheet 2365A，对比文件1中 30.0 和对比文件2中 nan 不同，在excel表行 5138，列 PM10。
# 在sheet 2365A，对比文件1中 28.0 和对比文件2中 nan 不同，在excel表行 5139，列 PM10。
# 在sheet 2365A，对比文件1中 28.0 和对比文件2中 nan 不同，在excel表行 5140，列 PM10。
# 在sheet 2365A，对比文件1中 28.0 和对比文件2中 nan 不同，在excel表行 5141，列 PM10。
# 在sheet 2365A，对比文件1中 21.0 和对比文件2中 nan 不同，在excel表行 5142，列 PM10。
# 在sheet 2365A，对比文件1中 19.0 和对比文件2中 nan 不同，在excel表行 5143，列 PM10。
# 在sheet 2365A，对比文件1中 15.0 和对比文件2中 nan 不同，在excel表行 5145，列 PM10。
# 在sheet 2365A，对比文件1中 18.0 和对比文件2中 nan 不同，在excel表行 5149，列 PM10。
# 在sheet 2365A，对比文件1中 25.0 和对比文件2中 nan 不同，在excel表行 5150，列 PM10。
# 在sheet 2365A，对比文件1中 9.0 和对比文件2中 nan 不同，在excel表行 5138，列 SO2。
# 在sheet 2365A，对比文件1中 15.0 和对比文件2中 nan 不同，在excel表行 5139，列 SO2。
# 在sheet 2365A，对比文件1中 16.0 和对比文件2中 nan 不同，在excel表行 5140，列 SO2。
# 在sheet 2365A，对比文件1中 11.0 和对比文件2中 nan 不同，在excel表行 5141，列 SO2。
# 在sheet 2365A，对比文件1中 4.0 和对比文件2中 nan 不同，在excel表行 5142，列 SO2。
# 在sheet 2365A，对比文件1中 4.0 和对比文件2中 nan 不同，在excel表行 5143，列 SO2。
# 在sheet 2365A，对比文件1中 11.0 和对比文件2中 nan 不同，在excel表行 5144，列 SO2。
# 在sheet 2365A，对比文件1中 6.0 和对比文件2中 nan 不同，在excel表行 5145，列 SO2。
# 在sheet 2365A，对比文件1中 15.0 和对比文件2中 nan 不同，在excel表行 5149，列 SO2。
# 在sheet 2365A，对比文件1中 8.0 和对比文件2中 nan 不同，在excel表行 5150，列 SO2。
# 在sheet 2365A，对比文件1中 nan 和对比文件2中 122.0 不同，在excel表行 8761，列 SO2。
# 在sheet 2365A，对比文件1中 nan 和对比文件2中 115.0 不同，在excel表行 8764，列 SO2。
# 在sheet 2365A，对比文件1中 6.0 和对比文件2中 nan 不同，在excel表行 5138，列 NO2。
# 在sheet 2365A，对比文件1中 5.0 和对比文件2中 nan 不同，在excel表行 5139，列 NO2。
# 在sheet 2365A，对比文件1中 2.0 和对比文件2中 nan 不同，在excel表行 5140，列 NO2。
# 在sheet 2365A，对比文件1中 2.0 和对比文件2中 nan 不同，在excel表行 5141，列 NO2。
# 在sheet 2365A，对比文件1中 3.0 和对比文件2中 nan 不同，在excel表行 5142，列 NO2。
# 在sheet 2365A，对比文件1中 2.0 和对比文件2中 nan 不同，在excel表行 5143，列 NO2。
# 在sheet 2365A，对比文件1中 2.0 和对比文件2中 nan 不同，在excel表行 5144，列 NO2。
# 在sheet 2365A，对比文件1中 4.0 和对比文件2中 nan 不同，在excel表行 5145，列 NO2。
# 在sheet 2365A，对比文件1中 16.0 和对比文件2中 nan 不同，在excel表行 5149，列 NO2。
# 在sheet 2365A，对比文件1中 11.0 和对比文件2中 nan 不同，在excel表行 5150，列 NO2。
# 在sheet 2365A，对比文件1中 29.0 和对比文件2中 nan 不同，在excel表行 5138，列 O3。
# 在sheet 2365A，对比文件1中 30.0 和对比文件2中 nan 不同，在excel表行 5139，列 O3。
# 在sheet 2365A，对比文件1中 31.0 和对比文件2中 nan 不同，在excel表行 5140，列 O3。
# 在sheet 2365A，对比文件1中 34.0 和对比文件2中 nan 不同，在excel表行 5141，列 O3。
# 在sheet 2365A，对比文件1中 40.0 和对比文件2中 nan 不同，在excel表行 5142，列 O3。
# 在sheet 2365A，对比文件1中 38.0 和对比文件2中 nan 不同，在excel表行 5143，列 O3。
# 在sheet 2365A，对比文件1中 37.0 和对比文件2中 nan 不同，在excel表行 5144，列 O3。
# 在sheet 2365A，对比文件1中 35.0 和对比文件2中 nan 不同，在excel表行 5145，列 O3。
# 在sheet 2365A，对比文件1中 32.0 和对比文件2中 nan 不同，在excel表行 5149，列 O3。
# 在sheet 2365A，对比文件1中 38.0 和对比文件2中 nan 不同，在excel表行 5150，列 O3。
# 在sheet 2365A，对比文件1中 41.0 和对比文件2中 nan 不同，在excel表行 5138，列 O3_8h。
# 在sheet 2365A，对比文件1中 30.0 和对比文件2中 nan 不同，在excel表行 5139，列 O3_8h。
# 在sheet 2365A，对比文件1中 30.0 和对比文件2中 nan 不同，在excel表行 5140，列 O3_8h。
# 在sheet 2365A，对比文件1中 32.0 和对比文件2中 nan 不同，在excel表行 5141，列 O3_8h。
# 在sheet 2365A，对比文件1中 34.0 和对比文件2中 nan 不同，在excel表行 5142，列 O3_8h。
# 在sheet 2365A，对比文件1中 35.0 和对比文件2中 nan 不同，在excel表行 5143，列 O3_8h。
# 在sheet 2365A，对比文件1中 35.0 和对比文件2中 nan 不同，在excel表行 5144，列 O3_8h。
# 在sheet 2365A，对比文件1中 35.0 和对比文件2中 nan 不同，在excel表行 5145，列 O3_8h。
# 在sheet 2365A，对比文件1中 34.0 和对比文件2中 nan 不同，在excel表行 5149，列 O3_8h。
# 在sheet 2365A，对比文件1中 34.0 和对比文件2中 nan 不同，在excel表行 5150，列 O3_8h。
# 在sheet 2365A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5138，列 CO。
# 在sheet 2365A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5139，列 CO。
# 在sheet 2365A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5140，列 CO。
# 在sheet 2365A，对比文件1中 0.8 和对比文件2中 nan 不同，在excel表行 5141，列 CO。
# 在sheet 2365A，对比文件1中 0.8 和对比文件2中 nan 不同，在excel表行 5142，列 CO。
# 在sheet 2365A，对比文件1中 0.8 和对比文件2中 nan 不同，在excel表行 5143，列 CO。
# 在sheet 2365A，对比文件1中 0.8 和对比文件2中 nan 不同，在excel表行 5144，列 CO。
# 在sheet 2365A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5145，列 CO。
# 在sheet 2365A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5149，列 CO。
# 在sheet 2365A，对比文件1中 0.9 和对比文件2中 nan 不同，在excel表行 5150，列 CO。
# 在sheet 2366A，对比文件1中 17.0 和对比文件2中 nan 不同，在excel表行 5138，列 PM2.5。
# 在sheet 2366A，对比文件1中 18.0 和对比文件2中 nan 不同，在excel表行 5139，列 PM2.5。
# 在sheet 2366A，对比文件1中 20.0 和对比文件2中 nan 不同，在excel表行 5140，列 PM2.5。
# 在sheet 2366A，对比文件1中 19.0 和对比文件2中 nan 不同，在excel表行 5141，列 PM2.5。
# 在sheet 2366A，对比文件1中 25.0 和对比文件2中 nan 不同，在excel表行 5142，列 PM2.5。
# 在sheet 2366A，对比文件1中 21.0 和对比文件2中 nan 不同，在excel表行 5143，列 PM2.5。
# 在sheet 2366A，对比文件1中 21.0 和对比文件2中 nan 不同，在excel表行 5144，列 PM2.5。
# 在sheet 2366A，对比文件1中 12.0 和对比文件2中 nan 不同，在excel表行 5145，列 PM2.5。
# 在sheet 2366A，对比文件1中 16.0 和对比文件2中 nan 不同，在excel表行 5149，列 PM2.5。
# 在sheet 2366A，对比文件1中 18.0 和对比文件2中 nan 不同，在excel表行 5150，列 PM2.5。
# 在sheet 2366A，对比文件1中 16.0 和对比文件2中 nan 不同，在excel表行 5151，列 PM2.5。
# 在sheet 2366A，对比文件1中 57.0 和对比文件2中 nan 不同，在excel表行 5138，列 PM10。
# 在sheet 2366A，对比文件1中 47.0 和对比文件2中 nan 不同，在excel表行 5139，列 PM10。
# 在sheet 2366A，对比文件1中 42.0 和对比文件2中 nan 不同，在excel表行 5140，列 PM10。
# 在sheet 2366A，对比文件1中 30.0 和对比文件2中 nan 不同，在excel表行 5141，列 PM10。
# 在sheet 2366A，对比文件1中 35.0 和对比文件2中 nan 不同，在excel表行 5142，列 PM10。
# 在sheet 2366A，对比文件1中 33.0 和对比文件2中 nan 不同，在excel表行 5143，列 PM10。
# 在sheet 2366A，对比文件1中 27.0 和对比文件2中 nan 不同，在excel表行 5144，列 PM10。
# 在sheet 2366A，对比文件1中 18.0 和对比文件2中 nan 不同，在excel表行 5145，列 PM10。
# 在sheet 2366A，对比文件1中 30.0 和对比文件2中 nan 不同，在excel表行 5149，列 PM10。
# 在sheet 2366A，对比文件1中 35.0 和对比文件2中 nan 不同，在excel表行 5150，列 PM10。
# 在sheet 2366A，对比文件1中 12.0 和对比文件2中 nan 不同，在excel表行 5138，列 SO2。
# 在sheet 2366A，对比文件1中 11.0 和对比文件2中 nan 不同，在excel表行 5139，列 SO2。
# 在sheet 2366A，对比文件1中 12.0 和对比文件2中 nan 不同，在excel表行 5140，列 SO2。
# 在sheet 2366A，对比文件1中 13.0 和对比文件2中 nan 不同，在excel表行 5141，列 SO2。
# 在sheet 2366A，对比文件1中 17.0 和对比文件2中 nan 不同，在excel表行 5142，列 SO2。
# 在sheet 2366A，对比文件1中 20.0 和对比文件2中 nan 不同，在excel表行 5143，列 SO2。
# 在sheet 2366A，对比文件1中 16.0 和对比文件2中 nan 不同，在excel表行 5144，列 SO2。
# 在sheet 2366A，对比文件1中 10.0 和对比文件2中 nan 不同，在excel表行 5145，列 SO2。
# 在sheet 2366A，对比文件1中 9.0 和对比文件2中 nan 不同，在excel表行 5149，列 SO2。
# 在sheet 2366A，对比文件1中 8.0 和对比文件2中 nan 不同，在excel表行 5150，列 SO2。
# 在sheet 2366A，对比文件1中 15.0 和对比文件2中 nan 不同，在excel表行 5138，列 NO2。
# 在sheet 2366A，对比文件1中 12.0 和对比文件2中 nan 不同，在excel表行 5139，列 NO2。
# 在sheet 2366A，对比文件1中 12.0 和对比文件2中 nan 不同，在excel表行 5140，列 NO2。
# 在sheet 2366A，对比文件1中 10.0 和对比文件2中 nan 不同，在excel表行 5141，列 NO2。
# 在sheet 2366A，对比文件1中 10.0 和对比文件2中 nan 不同，在excel表行 5142，列 NO2。
# 在sheet 2366A，对比文件1中 10.0 和对比文件2中 nan 不同，在excel表行 5143，列 NO2。
# 在sheet 2366A，对比文件1中 7.0 和对比文件2中 nan 不同，在excel表行 5144，列 NO2。
# 在sheet 2366A，对比文件1中 11.0 和对比文件2中 nan 不同，在excel表行 5145，列 NO2。
# 在sheet 2366A，对比文件1中 19.0 和对比文件2中 nan 不同，在excel表行 5149，列 NO2。
# 在sheet 2366A，对比文件1中 16.0 和对比文件2中 nan 不同，在excel表行 5150，列 NO2。
# 在sheet 2366A，对比文件1中 23.0 和对比文件2中 nan 不同，在excel表行 5138，列 O3。
# 在sheet 2366A，对比文件1中 25.0 和对比文件2中 nan 不同，在excel表行 5139，列 O3。
# 在sheet 2366A，对比文件1中 22.0 和对比文件2中 nan 不同，在excel表行 5140，列 O3。
# 在sheet 2366A，对比文件1中 28.0 和对比文件2中 nan 不同，在excel表行 5141，列 O3。
# 在sheet 2366A，对比文件1中 28.0 和对比文件2中 nan 不同，在excel表行 5142，列 O3。
# 在sheet 2366A，对比文件1中 27.0 和对比文件2中 nan 不同，在excel表行 5143，列 O3。
# 在sheet 2366A，对比文件1中 30.0 和对比文件2中 nan 不同，在excel表行 5144，列 O3。
# 在sheet 2366A，对比文件1中 26.0 和对比文件2中 nan 不同，在excel表行 5145，列 O3。
# 在sheet 2366A，对比文件1中 20.0 和对比文件2中 nan 不同，在excel表行 5149，列 O3。
# 在sheet 2366A，对比文件1中 29.0 和对比文件2中 nan 不同，在excel表行 5150，列 O3。
# 在sheet 2366A，对比文件1中 34.0 和对比文件2中 nan 不同，在excel表行 5138，列 O3_8h。
# 在sheet 2366A，对比文件1中 25.0 和对比文件2中 nan 不同，在excel表行 5139，列 O3_8h。
# 在sheet 2366A，对比文件1中 24.0 和对比文件2中 nan 不同，在excel表行 5140，列 O3_8h。
# 在sheet 2366A，对比文件1中 25.0 和对比文件2中 nan 不同，在excel表行 5141，列 O3_8h。
# 在sheet 2366A，对比文件1中 26.0 和对比文件2中 nan 不同，在excel表行 5142，列 O3_8h。
# 在sheet 2366A，对比文件1中 26.0 和对比文件2中 nan 不同，在excel表行 5143，列 O3_8h。
# 在sheet 2366A，对比文件1中 27.0 和对比文件2中 nan 不同，在excel表行 5144，列 O3_8h。
# 在sheet 2366A，对比文件1中 27.0 和对比文件2中 nan 不同，在excel表行 5145，列 O3_8h。
# 在sheet 2366A，对比文件1中 24.0 和对比文件2中 nan 不同，在excel表行 5149，列 O3_8h。
# 在sheet 2366A，对比文件1中 24.0 和对比文件2中 nan 不同，在excel表行 5150，列 O3_8h。
# 在sheet 2366A，对比文件1中 1.2 和对比文件2中 nan 不同，在excel表行 5138，列 CO。
# 在sheet 2366A，对比文件1中 1.2 和对比文件2中 nan 不同，在excel表行 5139，列 CO。
# 在sheet 2366A，对比文件1中 1.2 和对比文件2中 nan 不同，在excel表行 5140，列 CO。
# 在sheet 2366A，对比文件1中 1.2 和对比文件2中 nan 不同，在excel表行 5141，列 CO。
# 在sheet 2366A，对比文件1中 1.2 和对比文件2中 nan 不同，在excel表行 5142，列 CO。
# 在sheet 2366A，对比文件1中 1.2 和对比文件2中 nan 不同，在excel表行 5143，列 CO。
# 在sheet 2366A，对比文件1中 1.2 和对比文件2中 nan 不同，在excel表行 5144，列 CO。
# 在sheet 2366A，对比文件1中 1.3 和对比文件2中 nan 不同，在excel表行 5145，列 CO。
# 在sheet 2366A，对比文件1中 1.4 和对比文件2中 nan 不同，在excel表行 5149，列 CO。
# 在sheet 2366A，对比文件1中 1.3 和对比文件2中 nan 不同，在excel表行 5150，列 CO。
# 在sheet 2366A，对比文件1中 nan 和对比文件2中 4.3 不同，在excel表行 8771，列 CO。
# 2362A_PM2.5 有 11 处不同
# 2362A_PM10 有 10 处不同
# 2362A_SO2 有 10 处不同
# 2362A_NO2 有 10 处不同
# 2362A_O3 有 10 处不同
# 2362A_O3_8h 有 10 处不同
# 2362A_CO 有 10 处不同
# 2363A_PM2.5 有 11 处不同
# 2363A_PM10 有 10 处不同
# 2363A_SO2 有 13 处不同
# 2363A_NO2 有 10 处不同
# 2363A_O3 有 10 处不同
# 2363A_O3_8h 有 10 处不同
# 2363A_CO 有 10 处不同
# 2364A_PM2.5 有 11 处不同
# 2364A_PM10 有 10 处不同
# 2364A_SO2 有 11 处不同
# 2364A_NO2 有 10 处不同
# 2364A_O3 有 12 处不同
# 2364A_O3_8h 有 10 处不同
# 2364A_CO 有 11 处不同
# 2365A_PM2.5 有 11 处不同
# 2365A_PM10 有 9 处不同
# 2365A_SO2 有 12 处不同
# 2365A_NO2 有 10 处不同
# 2365A_O3 有 10 处不同
# 2365A_O3_8h 有 10 处不同
# 2365A_CO 有 10 处不同
# 2366A_PM2.5 有 11 处不同
# 2366A_PM10 有 10 处不同
# 2366A_SO2 有 10 处不同
# 2366A_NO2 有 10 处不同
# 2366A_O3 有 10 处不同
# 2366A_O3_8h 有 10 处不同
# 2366A_CO 有 11 处不同
# 一共有 364 处不同

# %%
df1 = pd.read_excel(path_new, sheet_name="2362A")
col_name = df1.columns[3:-3]  # 获取对比列名称（可以直接输入）

# %%
col_name
# Out:
# Index(['PM2.5', 'PM10', 'SO2', 'NO2', 'O3', 'O3_8h', 'CO'], dtype='object')
